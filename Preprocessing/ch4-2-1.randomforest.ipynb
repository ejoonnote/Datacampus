# %%
# ch4-2.py
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(module='sklearn*', action='ignore', category=DeprecationWarning)

# %%
# 데이터로드 (NHIS_OPEN_GJ_2017.csv : 데이터 원본 파일)
# encoding : 윈도우즈 환경에서의 한글 처리
# engine : python 3.6에서 한글이 포함된 파일이름 사용
rawData_org = pd.read_csv('datasets/국민건강정보/NHIS_OPEN_GJ_2017.csv', encoding='CP949', engine='python')

# %%
# 원본데이터의 튜플 수와 컬럼수 출력
rawData_org.shape
# Out:
# (1000000, 34)

# %%
# 의사결정트리에 사용할 속성리스트
feature_columns_to_use = ['성별코드', '연령대코드(5세단위)', '신장(5Cm단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)',
                    '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)', '트리글리세라이드', 'HDL콜레스테롤',
                    'LDL콜레스테롤', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '음주여부']

rawData = rawData_org[feature_columns_to_use]

# %%
# 속성값이 NULL인 튜플 제외
rawData = rawData.dropna()

# 인덱스 재설정
rawData.reset_index(inplace=True, drop=True)

# 원본데이터의 튜플 수와 컬럼수 출력
rawData.shape
# Out:
# (990910, 22)

# %%
import random as rd  # 샘플링을 위한 random 패키지 임포트

# 1) 샘플링을 통한 수량 축소
# 원본데이터 중 50,000개를 튜플만 샘플링
# len() : 데이터프레임의 크기를 구하는 함수
sample_idx = rd.sample(range(0, len(rawData)), 50000)

# 인덱스 값 정렬(오름차순)
sample_idx.sort()

sample_idx
# Out:
# [11,
#  15,
#  44,
#  60,
#  90,
#  114,
#  127,
#  129,
#  192,
#  195,
#  202,
#  206,
#  211,
#  213,
#  258,
#  279,
#  283,
#  338,
#  346,
#  358,
#  364,
#  365,
#  392,
#  398,
#  415,
#  471,
#  503,
#  505,
#  507,
#  513,
#  525,
#  529,
#  563,
#  596,
#  602,
#  605,
#  608,
#  614,
#  616,
#  623,
#  635,
#  640,
#  652,
#  670,
#  687,
#  712,
#  720,
#  746,
#  769,
#  791,
#  793,
#  798,
#  831,
#  835,
#  837,
#  844,
#  888,
#  900,
#  903,
#  906,
#  979,
#  1022,
#  1050,
#  1056,
#  1062,
#  1082,
#  1108,
#  1110,
#  1116,
#  1152,
#  1209,
#  1235,
#  1255,
#  1269,
#  1272,
#  1292,
#  1342,
#  1346,
#  1354,
#  1383,
#  1399,
#  1408,
#  1418,
#  1442,
#  1451,
#  1466,
#  1478,
#  1513,
#  1517,
#  1547,
#  1580,
#  1586,
#  1599,
#  1627,
#  1628,
#  1691,
#  1723,
#  1735,
#  1744,
#  1775,
#  1831,
#  1871,
#  1876,
#  1877,
#  1926,
#  1937,
#  1961,
#  1987,
#  1996,
#  2056,
#  2057,
#  2081,
#  2087,
#  2126,
#  2173,
#  2244,
#  2260,
#  2264,
#  2278,
#  2301,
#  2336,
#  2350,
#  2358,
#  2368,
#  2393,
#  2453,
#  2457,
#  2477,
#  2502,
#  2510,
#  2518,
#  2538,
#  2549,
#  2558,
#  2567,
#  2579,
#  2583,
#  2605,
#  2606,
#  2618,
#  2627,
#  2651,
#  2656,
#  2667,
#  2672,
#  2681,
#  2700,
#  2703,
#  2729,
#  2739,
#  2756,
#  2784,
#  18095,
#  18096,
#  18098,
#  18135,
#  18174,
#  18185,
#  18196,
#  18224,
#  18248,
#  18268,
#  18339,
#  18348,
#  18351,
#  18399,
#  18426,
#  18433,
#  18441,
#  18464,
#  18475,
#  18487,
#  18516,
#  18584,
#  18619,
#  18651,
#  18685,
#  18740,
#  18745,
#  18760,
#  18766,
#  18768,
#  18818,
#  18891,
#  18893,
#  18974,
#  18978,
#  18989,
#  18990,
#  19004,
#  19007,
#  19030,
#  19033,
#  19042,
#  19061,
#  19072,
#  19107,
#  19137,
#  19147,
#  19214,
#  19256,
#  19270,
#  19339,
#  19391,
#  19478,
#  19518,
#  19535,
#  19561,
#  19567,
#  19572,
#  19597,
#  19609,
#  19639,
#  19650,
#  19663,
#  19677,
#  19702,
#  19704,
#  19721,
#  19766,
#  19776,
#  19781,
#  19803,
#  19820,
#  19852,
#  19911,
#  19946,
#  19971,
#  19977,
#  19981,
#  20041,
#  20047,
#  20069,
#  20083,
#  20143,
#  20194,
#  20197,
#  20215,
#  20224,
#  20244,
#  20313,
#  20325,
#  20333,
#  20340,
#  20382,
#  20396,
#  20401,
#  20415,
#  ...]

# %%
# 샘플링 된 인덱스로 구성된 샘플 데이터프레임 생성
rawData_sample = rawData.loc[sample_idx]

rawData_sample.reset_index(inplace=True, drop=True) #  인덱스 재설정

# 첫 10개의 행만 출력
rawData_sample.head(10)
# Out:
#    성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0     2           10      155.0        45.0  65.2    0.2    0.2    1.0    1.0
# 1     2           15      150.0        45.0  69.0    0.6    0.8    1.0    1.0
# 2     1           10      165.0        75.0  87.5    1.0    1.2    1.0    1.0
# 3     1           15      160.0        65.0  93.0    0.6    0.6    1.0    1.0
# 4     2            8      155.0        70.0  80.0    1.5    1.2    1.0    1.0
# 5     1           15      175.0        70.0  89.0    0.7    0.7    2.0    2.0
# 6     1            9      180.0        85.0  93.0    0.9    1.2    1.0    1.0
# 7     2           10      150.0        45.0  75.0    1.0    0.5    1.0    1.0
# 8     2           10      155.0        60.0  78.0    1.2    1.5    1.0    1.0
# 9     1            7      170.0        70.0  76.3    0.9    0.9    1.0    1.0
#
#    수축기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0  124.0  ...     117.0      50.0      98.0  1.0      0.7        21.0
# 1  110.0  ...     155.0      64.0     119.0  1.0      0.8        19.0
# 2  123.0  ...     455.0      36.0     197.0  2.0      0.8        28.0
# 3  140.0  ...     115.0      58.0     130.0  1.0      1.2        22.0
# 4  113.0  ...      55.0      55.0     142.0  1.0      0.5        21.0
# 5  110.0  ...     107.0      63.0     116.0  1.0      1.2        28.0
# 6  132.0  ...      65.0      41.0      84.0  1.0      0.7        20.0
# 7  100.0  ...      91.0      53.0     158.0  2.0      1.0        21.0
# 8  124.0  ...     149.0      37.0      98.0  1.0      0.6        18.0
# 9  124.0  ...     883.0      30.0     159.0  1.0      1.2        26.0
#
#    (혈청지오티)ALT  감마지티피  흡연상태  음주여부
# 0        14.0   21.0   1.0   0.0
# 1        14.0   10.0   1.0   0.0
# 2        38.0   29.0   3.0   0.0
# 3        17.0   65.0   2.0   0.0
# 4        27.0   38.0   1.0   1.0
# 5        33.0   25.0   2.0   0.0
# 6        19.0   26.0   3.0   1.0
# 7         8.0   12.0   1.0   0.0
# 8        17.0   13.0   1.0   0.0
# 9        17.0   21.0   1.0   1.0
#
# [10 rows x 22 columns]

# %%
rawData_sample.shape
# Out:
# (50000, 22)

# %%
# nonnumeric 속성을 categrical 데이터로 변환
nonnumeric_columns = ['성별코드','음주여부']

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in nonnumeric_columns:
    rawData_sample[feature] = le.fit_transform(rawData_sample[feature])

# %%
rawData_sample.head(10)
# Out:
#    성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0     1           10      155.0        45.0  65.2    0.2    0.2    1.0    1.0
# 1     1           15      150.0        45.0  69.0    0.6    0.8    1.0    1.0
# 2     0           10      165.0        75.0  87.5    1.0    1.2    1.0    1.0
# 3     0           15      160.0        65.0  93.0    0.6    0.6    1.0    1.0
# 4     1            8      155.0        70.0  80.0    1.5    1.2    1.0    1.0
# 5     0           15      175.0        70.0  89.0    0.7    0.7    2.0    2.0
# 6     0            9      180.0        85.0  93.0    0.9    1.2    1.0    1.0
# 7     1           10      150.0        45.0  75.0    1.0    0.5    1.0    1.0
# 8     1           10      155.0        60.0  78.0    1.2    1.5    1.0    1.0
# 9     0            7      170.0        70.0  76.3    0.9    0.9    1.0    1.0
#
#    수축기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0  124.0  ...     117.0      50.0      98.0  1.0      0.7        21.0
# 1  110.0  ...     155.0      64.0     119.0  1.0      0.8        19.0
# 2  123.0  ...     455.0      36.0     197.0  2.0      0.8        28.0
# 3  140.0  ...     115.0      58.0     130.0  1.0      1.2        22.0
# 4  113.0  ...      55.0      55.0     142.0  1.0      0.5        21.0
# 5  110.0  ...     107.0      63.0     116.0  1.0      1.2        28.0
# 6  132.0  ...      65.0      41.0      84.0  1.0      0.7        20.0
# 7  100.0  ...      91.0      53.0     158.0  2.0      1.0        21.0
# 8  124.0  ...     149.0      37.0      98.0  1.0      0.6        18.0
# 9  124.0  ...     883.0      30.0     159.0  1.0      1.2        26.0
#
#    (혈청지오티)ALT  감마지티피  흡연상태  음주여부
# 0        14.0   21.0   1.0     0
# 1        14.0   10.0   1.0     0
# 2        38.0   29.0   3.0     0
# 3        17.0   65.0   2.0     0
# 4        27.0   38.0   1.0     1
# 5        33.0   25.0   2.0     0
# 6        19.0   26.0   3.0     1
# 7         8.0   12.0   1.0     0
# 8        17.0   13.0   1.0     0
# 9        17.0   21.0   1.0     1
#
# [10 rows x 22 columns]

# %%
# 소스 데이터프레임에서 분류(classification)을 위한 속성 집합
X = rawData_sample.loc[:, feature_columns_to_use[:-1]]  
y = rawData_sample.loc[:, '음주여부']  # 분류 클래스(class)

from sklearn.model_selection import train_test_split  # 분석모형 선택에 관련된 모듈
    
# 자동으로 데이터셋을 트레이닝셋과 테스트셋으로 분리해주는 함수로
# 트레이닝셋과 데이터셋의 비율을 7:3으로 세팅함
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# RMSLE 계산하는 사용자정의 함수
from sklearn.metrics import make_scorer

def rmsle(predicted_values, actual_values) :
    # 넘파이로 배열 형태로 변환
    predicted_values = np.array(predicted_values)
    actual_values = np.array(actual_values)
    
    # 예측값과 실제값에 1을 더하고 로그를 씌움
    log_predict = np.log(predicted_values + 1)
    log_actual = np.log(actual_values + 1)
    
    # 위에서 계산한 예측값에서 실제값을 빼주고 제곱을 함
    difference = log_predict - log_actual
    # difference = (log_predict - log_actual) ** 2
    difference = np.square(difference)
    
    # 평균값 구함
    mean_difference = difference.mean()
    
    # 다시 루트를 씌움
    score = np.sqrt(mean_difference)
    
    return score

rmsle_scorer = make_scorer(rmsle)
rmsle_scorer
# Out:
# make_scorer(rmsle)

# %%
# Scikit-Learn 패키지 : 머신 러닝 교육 및 실무를 위한 패키지로 샘플 데이터셋,
# 다양한 기계학습 기법에 대한 함수 등을 포함하고 있음
from sklearn.ensemble import RandomForestClassifier  # 랜덤포리스트 기법에 관련된 모듈

# DecisionTreeClassifier() : 의사결정트리를 생성하는 함수
random_forest = RandomForestClassifier(n_estimators=20, random_state=0)
random_forest
# Out:
# RandomForestClassifier(n_estimators=20, random_state=0)

# %%
# KFold 교차검증
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# 트레이닝셋에 대한 KFold 교차검증 수
# %time score = cross_val_score(random_forest, X_train, y_train, cv=k_fold, scoring=rmsle_scorer)
score = score.mean()

# 0에 근접할수록 좋은 데이터
print("Score= {0:.5f}".format(score))
# Out:
# Wall time: 21.1 s
# Score= 0.36941

# %%
# fit() : 트레이닝 데이터셋을 대상으로 의사결정트리 학습 진행
random_forest.fit(X_train, y_train)

# tree.predict() 함수를 활용하여 의사결정트리를 대상으로 테스트셋을 예측
y_pred_tr = random_forest.predict(X_test)

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(random_forest.score(X_train, y_train)))
print("Test Set Score1 : {:.2f}".format(random_forest.score(X_test, y_test)))
# Out:
# Train Set Score1 : 1.00
# Test Set Score1 : 0.71

# %%
from sklearn.metrics import accuracy_score  # 분류 정확도(classification accuracy)를 계산하는 모듈

# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.71

# %%
# 속성(feature) 별 중요도를 저장하는 데이터프레임 생성 
sel_feature = pd.DataFrame({'중요도' : random_forest.feature_importances_}, index = feature_columns_to_use[:-1])

# 중요도의 내림차순으로 정렬
sel_feature.sort_values(by='중요도', ascending=False)
# Out:
#                   중요도
# 감마지티피        0.082352
# 연령대코드(5세단위)  0.079162
# HDL콜레스테롤     0.070236
# 트리글리세라이드     0.064683
# LDL콜레스테롤     0.063817
# 흡연상태         0.058770
# 식전혈당(공복혈당)   0.056604
# 신장(5Cm단위)    0.056102
# 허리둘레         0.055883
# (혈청지오티)ALT   0.055119
# 수축기혈압        0.052639
# 이완기혈압        0.049854
# (혈청지오티)AST   0.049389
# 성별코드         0.048822
# 체중(5Kg 단위)   0.039933
# 혈청크레아티닌      0.038596
# 시력(우)        0.034385
# 시력(좌)        0.034025
# 요단백          0.005563
# 청력(좌)        0.002082
# 청력(우)        0.001985
