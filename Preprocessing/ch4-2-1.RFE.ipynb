# %%
# ch4-2.py
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(module='sklearn*', action='ignore', category=DeprecationWarning)

# %%
# 데이터로드 (ch4-2(붓꽃데이터).csv : 데이터 원본 파일)
# encoding : 윈도우즈 환경에서의 한글 처리
# engine : python 3.6에서 한글이 포함된 파일이름 사용
rawData_org = pd.read_csv('datasets/국민건강정보/NHIS_OPEN_GJ_2017.csv', encoding='CP949', engine='python')

# %%
# 원본데이터의 튜플 수와 컬럼수 출력
rawData_org.shape
# Out:
# (1000000, 34)

# %%
# 의사결정트리에 사용할 속성리스트
feature_columns_to_use = ['성별코드', '연령대코드(5세단위)', '신장(5Cm단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)',
                    '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)', '트리글리세라이드', 'HDL콜레스테롤',
                    'LDL콜레스테롤', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '음주여부']

rawData = rawData_org[feature_columns_to_use]

# %%
# 속성값이 NULL인 튜플 제외
rawData = rawData.dropna()

# %%
# 인덱스 재설정
rawData.reset_index(inplace=True, drop=True)

# 원본데이터의 튜플 수와 컬럼수 출력
rawData.shape
# Out:
# (990910, 22)

# %%
import random as rd  # 샘플링을 위한 random 패키지 임포트

# 1) 샘플링을 통한 수량 축소
# 원본데이터 중 50,000개를 튜플만 샘플링
# len() : 데이터프레임의 크기를 구하는 함수
sample_idx = rd.sample(range(0, len(rawData)), 50000)

# 인덱스 값 정렬(오름차순)
sample_idx.sort()

sample_idx
# Out:
# [86,
#  105,
#  156,
#  176,
#  185,
#  191,
#  231,
#  232,
#  319,
#  325,
#  339,
#  380,
#  396,
#  469,
#  475,
#  532,
#  537,
#  562,
#  573,
#  580,
#  606,
#  627,
#  653,
#  690,
#  691,
#  738,
#  784,
#  806,
#  817,
#  859,
#  894,
#  956,
#  967,
#  988,
#  999,
#  1002,
#  1003,
#  1030,
#  1063,
#  1069,
#  1074,
#  1101,
#  1107,
#  1109,
#  1127,
#  1154,
#  1159,
#  1190,
#  1194,
#  1249,
#  1259,
#  1264,
#  1267,
#  1269,
#  1301,
#  1330,
#  1338,
#  1359,
#  1373,
#  1381,
#  1389,
#  1437,
#  1445,
#  1466,
#  1470,
#  1474,
#  1561,
#  1583,
#  1608,
#  1627,
#  1629,
#  1650,
#  1655,
#  1708,
#  1719,
#  1787,
#  1788,
#  1820,
#  1825,
#  1875,
#  1897,
#  1908,
#  1945,
#  1966,
#  2004,
#  2010,
#  2026,
#  2029,
#  2032,
#  2041,
#  2073,
#  2086,
#  2100,
#  2111,
#  2120,
#  2147,
#  2202,
#  2252,
#  2257,
#  2262,
#  2328,
#  2359,
#  2363,
#  2384,
#  2393,
#  2395,
#  2409,
#  2428,
#  2444,
#  2459,
#  2468,
#  2478,
#  2534,
#  2563,
#  2589,
#  2627,
#  2629,
#  2631,
#  2640,
#  2642,
#  2657,
#  2658,
#  2775,
#  2785,
#  2792,
#  2843,
#  2878,
#  2893,
#  2960,
#  2977,
#  3004,
#  3067,
#  3078,
#  3081,
#  3109,
#  3130,
#  3139,
#  3163,
#  3169,
#  3194,
#  3207,
#  3225,
#  3237,
#  3268,
#  3284,
#  3290,
#  3297,
#  3303,
#  3304,
#  3307,
#  3315,
#  3333,
#  3359,
#  3364,
#  3387,
#  3402,
#  3406,
#  3408,
#  3467,
#  3530,
#  3545,
#  3566,
#  3574,
#  3579,
#  3595,
#  3621,
#  3635,
#  3660,
#  3663,
#  3667,
#  3672,
#  3680,
#  3711,
#  3715,
#  3717,
#  3719,
#  3725,
#  3740,
#  3768,
#  3770,
#  3771,
#  3784,
#  3813,
#  3818,
#  3833,
#  3839,
#  3845,
#  3879,
#  3882,
#  3883,
#  3904,
#  3906,
#  3918,
#  3937,
#  3980,
#  4018,
#  4026,
#  4060,
#  4068,
#  4109,
#  4114,
#  4115,
#  4194,
#  4222,
#  4232,
#  4243,
#  4246,
#  4262,
#  4264,
#  4367,
#  4380,
#  4384,
#  4393,
#  4427,
#  4471,
#  4478,
#  4481,
#  4508,
#  4509,
#  4557,
#  4562,
#  4583,
#  4614,
#  4667,
#  4711,
#  4716,
#  4730,
#  4753,
#  4775,
#  4798,
#  4831,
#  4854,
#  4888,
#  4901,
#  4918,
#  4963,
#  4964,
#  4986,
#  5018,
#  5062,
#  5066,
#  5093,
#  5117,
#  5173,
#  5182,
#  5198,
#  5249,
#  5263,
#  5264,
#  5270,
#  5278,
#  5282,
#  5300,
#  5326,
#  5359,
#  5406,
#  5420,
#  5453,
#  5491,
#  5509,
#  5567,
#  5573,
#  5617,
#  5622,
#  5681,
#  5727,
#  5781,
#  5799,
#  5843,
#  5886,
#  5921,
#  5952,
#  5963,
#  5966,
#  6012,
#  6114,
#  6132,
#  6138,
#  6188,
#  6196,
#  6217,
#  6234,
#  6241,
#  6261,
#  6285,
#  6299,
#  6307,
#  6313,
#  6366,
#  6371,
#  6402,
#  6408,
#  6415,
#  6417,
#  6429,
#  6458,
#  6479,
#  6518,
#  6565,
#  6567,
#  6582,
#  6583,
#  6588,
#  6696,
#  6754,
#  6765,
#  6774,
#  6808,
#  6818,
#  6840,
#  6848,
#  6863,
#  6870,
#  6896,
#  6911,
#  6925,
#  6943,
#  6976,
#  7029,
#  7030,
#  7057,
#  7064,
#  7085,
#  7088,
#  7119,
#  7131,
#  7146,
#  7177,
#  7212,
#  7213,
#  7241,
#  7325,
#  7333,
#  7380,
#  7386,
#  7392,
#  7412,
#  7416,
#  7493,
#  7497,
#  7500,
#  7508,
#  7513,
#  7530,
#  7533,
#  7534,
#  7537,
#  7542,
#  7546,
#  7550,
#  7625,
#  7635,
#  7687,
#  7689,
#  7739,
#  7746,
#  7797,
#  7800,
#  7809,
#  7811,
#  7818,
#  7830,
#  7849,
#  7894,
#  7902,
#  7927,
#  7942,
#  7952,
#  7960,
#  7962,
#  7979,
#  7984,
#  7994,
#  8009,
#  8018,
#  8040,
#  8054,
#  8055,
#  8095,
#  8111,
#  8117,
#  8128,
#  8133,
#  8147,
#  8152,
#  8224,
#  8233,
#  8246,
#  8253,
#  8275,
#  8294,
#  8316,
#  8334,
#  8335,
#  8356,
#  8368,
#  8432,
#  8506,
#  8512,
#  8549,
#  8564,
#  8569,
#  8582,
#  8597,
#  8604,
#  8613,
#  8614,
#  8624,
#  8633,
#  8644,
#  8680,
#  8715,
#  8717,
#  8734,
#  8765,
#  8768,
#  8778,
#  8790,
#  8837,
#  8886,
#  8889,
#  8899,
#  8905,
#  8921,
#  8955,
#  20055,
#  20069,
#  20075,
#  20101,
#  20128,
#  20129,
#  20133,
#  20156,
#  20193,
#  20206,
#  20214,
#  20243,
#  20245,
#  20247,
#  20268,
#  20314,
#  20330,
#  20338,
#  20368,
#  20369,
#  20372,
#  20387,
#  20389,
#  20393,
#  20408,
#  20475,
#  20499,
#  20523,
#  20557,
#  20559,
#  20589,
#  20591,
#  20593,
#  20611,
#  20615,
#  20639,
#  20653,
#  20655,
#  20660,
#  20665,
#  20678,
#  20689,
#  20692,
#  20695,
#  20697,
#  20758,
#  20800,
#  ...]

# %%
# 샘플링 된 인덱스로 구성된 샘플 데이터프레임 생성
rawData_sample = rawData.loc[sample_idx]

rawData_sample.reset_index(inplace=True, drop=True) #  인덱스 재설정

# 첫 10개의 행만 출력
rawData_sample.head(10)
# Out:
#    성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)   허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0     2            9      160.0        55.0   73.0    1.0    1.0    1.0
# 1     1            8      170.0        75.0   91.0    0.7    0.5    1.0
# 2     1           13      160.0        65.0   89.0    0.5    0.5    1.0
# 3     1            8      180.0       100.0   96.0    1.0    1.0    1.0
# 4     2           10      165.0        65.0   82.4    1.2    1.2    2.0
# 5     1           12      165.0        65.0   77.0    0.6    0.1    1.0
# 6     1            6      165.0        65.0   73.0    0.8    0.8    1.0
# 7     1           14      175.0        80.0  101.0    0.8    0.7    1.0
# 8     2           15      150.0        45.0   82.0    0.6    0.5    2.0
# 9     1            6      185.0        75.0   86.0    0.8    0.7    1.0
#
#    청력(우)  수축기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0    1.0  129.0  ...      34.0      62.0     118.0  1.0      0.9        19.0
# 1    1.0  122.0  ...      77.0      43.0     104.0  1.0      0.8        21.0
# 2    1.0  131.0  ...     171.0      44.0      35.0  2.0      1.1        20.0
# 3    1.0  108.0  ...     268.0      71.0     118.0  1.0      1.1        29.0
# 4    2.0  118.0  ...     145.0      56.0      92.0  1.0      0.5        16.0
# 5    1.0  132.0  ...     219.0      56.0     168.0  1.0      1.0        30.0
# 6    1.0  131.0  ...      82.0      69.0     102.0  1.0      0.7        14.0
# 7    1.0  126.0  ...     103.0      93.0     102.0  1.0      0.8        34.0
# 8    1.0  132.0  ...     307.0      32.0       1.0  1.0      0.8        27.0
# 9    1.0  118.0  ...     103.0      64.0     117.0  1.0      0.8        19.0
#
#    (혈청지오티)ALT  감마지티피  흡연상태  음주여부
# 0        17.0   19.0   1.0   0.0
# 1        15.0   32.0   2.0   0.0
# 2        12.0   20.0   2.0   1.0
# 3        25.0   82.0   3.0   1.0
# 4        14.0   13.0   1.0   0.0
# 5        34.0   42.0   2.0   1.0
# 6        13.0   14.0   1.0   1.0
# 7        40.0   53.0   2.0   1.0
# 8        21.0   27.0   1.0   0.0
# 9        25.0   30.0   1.0   0.0
#
# [10 rows x 22 columns]

# %%
rawData_sample.shape
# Out:
# (50000, 22)

# %%
# nonnumeric 속성을 categrical 데이터로 변환
nonnumeric_columns = ['성별코드','음주여부']

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in nonnumeric_columns:
    rawData_sample[feature] = le.fit_transform(rawData_sample[feature])

# %%
# 소스 데이터프레임에서 분류(classification)을 위한 속성 집합
X = rawData_sample.loc[:, feature_columns_to_use[:-1]]  
y = rawData_sample.loc[:, '음주여부']  # 분류 클래스(class)

from sklearn.model_selection import train_test_split  # 분석모형 선택에 관련된 모듈
    
# 자동으로 데이터셋을 트레이닝셋과 테스트셋으로 분리해주는 함수로
# 트레이닝셋과 데이터셋의 비율을 7:3으로 세팅함
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Scikit-Learn 패키지 : 머신 러닝 교육 및 실무를 위한 패키지로 샘플 데이터셋,
# 다양한 기계학습 기법에 대한 함수 등을 포함하고 있음
from sklearn.ensemble import RandomForestClassifier  # 랜덤포리스트 기법에 관련된 모듈

# DecisionTreeClassifier() : 의사결정트리를 생성하는 함수
random_forest = RandomForestClassifier(n_estimators=20, random_state=0)
random_forest
# Out:
# RandomForestClassifier(n_estimators=20, random_state=0)

# %%
# fit() : 트레이닝 데이터셋을 대상으로 의사결정트리 학습 진행
random_forest.fit(X_train, y_train)

# tree.predict() 함수를 활용하여 의사결정트리를 대상으로 테스트셋을 예측
y_pred_tr = random_forest.predict(X_test)

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(random_forest.score(X_train, y_train)))
print("Test Set Score1 : {:.2f}".format(random_forest.score(X_test, y_test)))
# Out:
# Train Set Score1 : 1.00
# Test Set Score1 : 0.71

# %%
from sklearn.metrics import accuracy_score  # 분류 정확도(classification accuracy)를 계산하는 모듈

# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.71

# %%
# RFE(Recursive Feature Elimination)
from sklearn.feature_selection import RFE

select = RFE(RandomForestClassifier(n_estimators=20, random_state=0), n_features_to_select = 10)
select.fit(X_train, y_train)
select
# Out:
# RFE(estimator=RandomForestClassifier(n_estimators=20, random_state=0),
#     n_features_to_select=10)

# %%
X_train_RFE = select.transform(X_train)
X_test_RFE = select.transform(X_test)
random_forest.fit(X_train_RFE, y_train)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=0)

# %%
# 속성(feature) 별 중요도를 저장하는 데이터프레임 생성 
sel_feature = pd.DataFrame({'중요도' : select.ranking_}, index = feature_columns_to_use[:-1])

# 중요도의 내림차순으로 정렬
sel_feature.sort_values(by='중요도', ascending=True)
# Out:
#              중요도
# 흡연상태           1
# 연령대코드(5세단위)    1
# 신장(5Cm단위)      1
# 허리둘레           1
# LDL콜레스테롤       1
# HDL콜레스테롤       1
# 트리글리세라이드       1
# 수축기혈압          1
# 감마지티피          1
# 식전혈당(공복혈당)     1
# (혈청지오티)ALT     2
# (혈청지오티)AST     3
# 이완기혈압          4
# 체중(5Kg 단위)     5
# 성별코드           6
# 혈청크레아티닌        7
# 시력(좌)          8
# 시력(우)          9
# 요단백           10
# 청력(좌)         11
# 청력(우)         12

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(random_forest.score(X_train_RFE, y_train)))
print("Test Set Score1 : {:.2f}".format(random_forest.score(X_test_RFE, y_test)))
# Out:
# Train Set Score1 : 1.00
# Test Set Score1 : 0.70

# %%
# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
y_pred_tr = random_forest.predict(X_test_RFE)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.70
