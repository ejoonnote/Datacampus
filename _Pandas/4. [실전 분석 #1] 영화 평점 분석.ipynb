# %% [markdown]
# # 영화 평점 분석 실습

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %% [markdown]
# ## 1. 영화 평점 데이터 적재 및 전처리

# %%
# 사용자 데이터 읽어오기
users = pd.read_csv('data/movielens/users.dat', sep = '::', engine = 'python',
                   names = ['사용자아이디', '성별','연령','직업','지역'])
users.head()
# Out:
#    사용자아이디 성별  연령  직업     지역
# 0       1  F   1  10  48067
# 1       2  M  56  16  70072
# 2       3  M  25  15  55117
# 3       4  M  45   7  02460
# 4       5  M  25  20  55455

# %%
# 평점 데이터 읽어오기
ratings = pd.read_csv('data/movielens/ratings.dat', sep = '::', engine = 'python',
                   names = ['사용자아이디', '영화아이디','평점','타임스탬프'])
ratings.head()
# Out:
#    사용자아이디  영화아이디  평점      타임스탬프
# 0       1   1193   5  978300760
# 1       1    661   3  978302109
# 2       1    914   3  978301968
# 3       1   3408   4  978300275
# 4       1   2355   5  978824291

# %%
# 영화데이터 읽어오기
movies = pd.read_csv('data/movielens/movies.dat', sep = '::', engine = 'python',
                   names = ['영화아이디','영화제목','장르'], encoding = 'latin-1')
movies.head()
# Out:
#    영화아이디                                영화제목                            장르
# 0      1                    Toy Story (1995)   Animation|Children's|Comedy
# 1      2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2      3             Grumpier Old Men (1995)                Comedy|Romance
# 3      4            Waiting to Exhale (1995)                  Comedy|Drama
# 4      5  Father of the Bride Part II (1995)                        Comedy

# %%
users.shape
# Out:
# (6040, 5)

# %%
ratings.shape
# Out:
# (1000209, 4)

# %%
movies.shape
# Out:
# (3883, 3)

# %%
print('사용자 수:', len(users))
print('평점 수:', len(ratings))
print('영화 수:', len(movies))
# Out:
# 사용자 수: 6040
# 평점 수: 1000209
# 영화 수: 3883

# %%
#평점을 한번도 안 준 사용자가 있는가? -> 없음
ratings.사용자아이디.nunique()
# Out:
# 6040

# %%
#평점이 하나도 없는 영화 있나? -> 177개 영화의 평점이 없음
ratings.영화아이디.nunique()
# Out:
# 3706

# %%
#영화제목이 중복되는게 있는지 체크
#영화 아이디는 고유한데 제목이 중복이 있을 수도 있음
movies.nunique()
# Out:
# 영화아이디    3883
# 영화제목     3883
# 장르        301
# dtype: int64

# %%
#3개의 데이터프레임을 하나로 합치기
data = pd.merge(users, ratings)
data = pd.merge(data, movies)
data.head()
# Out:
#    사용자아이디 성별  연령  직업     지역  영화아이디  평점      타임스탬프  \
# 0       1  F   1  10  48067   1193   5  978300760
# 1       2  M  56  16  70072   1193   5  978298413
# 2      12  M  25  12  32793   1193   4  978220179
# 3      15  M  25   7  22903   1193   4  978199279
# 4      17  M  50   1  95350   1193   5  978158471
#
#                                      영화제목     장르
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# ## 2. 보고 싶은 영화 찾기
# 영화들의 평점 평균을 구하여, 사람들에게 인정받는 (평점이 높은) 영화 찾기

# %%
# 영화들의 평점 평균을 구하여, 평점이 높은 영화 찾기 
# data.pivot_table(index = ['영화아이디','영화제목'],
#                 values = '평점',
#                 aggfunc='mean').sort_values('평점',ascending=False)

data.pivot_table(index = ['영화아이디','영화제목'],
                values = '평점',
                aggfunc='mean').nlargest(10,'평점')
# Out:
#                                                   평점
# 영화아이디 영화제목
# 787   Gate of Heavenly Peace, The (1995)         5.0
# 989   Schlafes Bruder (Brother of Sleep) (1995)  5.0
# 1830  Follow the Bitch (1998)                    5.0
# 3172  Ulysses (Ulisse) (1954)                    5.0
# 3233  Smashing Time (1967)                       5.0
# 3280  Baby, The (1973)                           5.0
# 3382  Song of Freedom (1936)                     5.0
# 3607  One Little Indian (1973)                   5.0
# 3656  Lured (1947)                               5.0
# 3881  Bittersweet Motel (2000)                   5.0

# %% [markdown]
# 평균 평점이 만점인 영화들이 최상위에 위치함.
# 일반적으로 평점이 만점인 경우는 대부분 평점의 개수가 매우 적은 경우이므로, 이를 확인하기 위해 평점의 개수도 함께 구해본다.

# %%
data.pivot_table(index = ['영화아이디','영화제목'],
                values = '평점',
                aggfunc=['mean','count'])
# Out:
#                                               mean count
#                                                 평점    평점
# 영화아이디 영화제목
# 1     Toy Story (1995)                    4.146846  2077
# 2     Jumanji (1995)                      3.201141   701
# 3     Grumpier Old Men (1995)             3.016736   478
# 4     Waiting to Exhale (1995)            2.729412   170
# 5     Father of the Bride Part II (1995)  3.006757   296
# ...                                            ...   ...
# 3948  Meet the Parents (2000)             3.635731   862
# 3949  Requiem for a Dream (2000)          4.115132   304
# 3950  Tigerland (2000)                    3.666667    54
# 3951  Two Family House (2000)             3.900000    40
# 3952  Contender, The (2000)               3.780928   388
#
# [3706 rows x 2 columns]

# %%
data.pivot_table(index = ['영화아이디','영화제목'],
                values = '평점',
                aggfunc=['mean','count']).nlargest(10,('mean','평점'))
# Out:
#                                                 mean count
#                                                   평점    평점
# 영화아이디 영화제목
# 787   Gate of Heavenly Peace, The (1995)         5.0     3
# 989   Schlafes Bruder (Brother of Sleep) (1995)  5.0     1
# 1830  Follow the Bitch (1998)                    5.0     1
# 3172  Ulysses (Ulisse) (1954)                    5.0     1
# 3233  Smashing Time (1967)                       5.0     2
# 3280  Baby, The (1973)                           5.0     1
# 3382  Song of Freedom (1936)                     5.0     1
# 3607  One Little Indian (1973)                   5.0     1
# 3656  Lured (1947)                               5.0     1
# 3881  Bittersweet Motel (2000)                   5.0     1

# %%
#평점이 평균 4.5이상이고 평점의 개수도 100개 이상이 영화 선청
ex = data.pivot_table(index = ['영화아이디','영화제목'],
                values = '평점',
                aggfunc=['mean','count'])

ex.columns =['평균', '개수']
ex
# Out:
#                                                 평균    개수
# 영화아이디 영화제목
# 1     Toy Story (1995)                    4.146846  2077
# 2     Jumanji (1995)                      3.201141   701
# 3     Grumpier Old Men (1995)             3.016736   478
# 4     Waiting to Exhale (1995)            2.729412   170
# 5     Father of the Bride Part II (1995)  3.006757   296
# ...                                            ...   ...
# 3948  Meet the Parents (2000)             3.635731   862
# 3949  Requiem for a Dream (2000)          4.115132   304
# 3950  Tigerland (2000)                    3.666667    54
# 3951  Two Family House (2000)             3.900000    40
# 3952  Contender, The (2000)               3.780928   388
#
# [3706 rows x 2 columns]

# %%
ex[(ex['평균']>=4.5) & (ex['개수']>1000)]
# Out:
#                                               평균    개수
# 영화아이디 영화제목
# 50    Usual Suspects, The (1995)        4.517106  1783
# 318   Shawshank Redemption, The (1994)  4.554558  2227
# 527   Schindler's List (1993)           4.510417  2304
# 858   Godfather, The (1972)             4.524966  2223

# %% [markdown]
# ## [실습 #1] 여자들이 좋아하는 영화 찾기
# ### - 여성 평점이 4.0 이상이고 여성 평점의 개수가 500개 이상인 영화

# %%
# data[data.성별 == 'F'].pivot_table(index = '영화제목', values = '평점', aggfunc =['mean','count'])
ex1 = data.pivot_table(index='영화제목', columns='성별', values='평점', aggfunc =['mean','count'])

# %%
#여성 데이터 가져오기
ex1_F = ex1.xs('F', axis=1, level=1)
ex1_F
# Out:
#                                                 mean  count
# 영화제목
# $1,000,000 Duck (1971)                      3.375000   16.0
# 'Night Mother (1986)                        3.388889   36.0
# 'Til There Was You (1997)                   2.675676   37.0
# 'burbs, The (1989)                          2.793478   92.0
# ...And Justice for All (1979)               3.828571   35.0
# ...                                              ...    ...
# Zed & Two Noughts, A (1985)                 3.500000    8.0
# Zero Effect (1998)                          3.864407   59.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)       NaN    NaN
# Zeus and Roxanne (1997)                     2.777778    9.0
# eXistenZ (1999)                             3.098592   71.0
#
# [3706 rows x 2 columns]

# %%
여성인기영화 = ex1_F[(ex1_F['mean']>=4.0)&(ex1_F['count']>=500)]

# %%
여성인기영화
# Out:
#                                                         mean  count
# 영화제목
# American Beauty (1999)                              4.238901  946.0
# Being John Malkovich (1999)                         4.159930  569.0
# Braveheart (1995)                                   4.016484  546.0
# Casablanca (1942)                                   4.300990  505.0
# E.T. the Extra-Terrestrial (1982)                   4.089850  601.0
# Fargo (1996)                                        4.217656  657.0
# Forrest Gump (1994)                                 4.045031  644.0
# L.A. Confidential (1997)                            4.106007  566.0
# Matrix, The (1999)                                  4.128405  514.0
# Princess Bride, The (1987)                          4.342767  636.0
# Pulp Fiction (1994)                                 4.071956  542.0
# Raiders of the Lost Ark (1981)                      4.332168  572.0
# Saving Private Ryan (1998)                          4.114783  575.0
# Schindler's List (1993)                             4.562602  615.0
# Shakespeare in Love (1998)                          4.181704  798.0
# Shawshank Redemption, The (1994)                    4.539075  627.0
# Silence of the Lambs, The (1991)                    4.271955  706.0
# Sixth Sense, The (1999)                             4.477410  664.0
# Star Wars: Episode IV - A New Hope (1977)           4.302937  647.0
# Star Wars: Episode V - The Empire Strikes Back ...  4.106481  648.0
# Toy Story (1995)                                    4.187817  591.0
# Wizard of Oz, The (1939)                            4.355030  507.0

# %% [markdown]
# ## [실습 #2] 실습 #1에서 구한 영화(여성인기영화)의 장르를 분석해 보자.
# 여성인기영화의 장르 통계 구하기
#
# 예를 들어, 여성인기영화 중 Drama 장르의 영화는 10개, Action 영화는 3개, ...

# %%
movies
# Out:
#       영화아이디                                영화제목                            장르
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# ...     ...                                 ...                           ...
# 3878   3948             Meet the Parents (2000)                        Comedy
# 3879   3949          Requiem for a Dream (2000)                         Drama
# 3880   3950                    Tigerland (2000)                         Drama
# 3881   3951             Two Family House (2000)                         Drama
# 3882   3952               Contender, The (2000)                Drama|Thriller
#
# [3883 rows x 3 columns]

# %%
여성인기영화.index
# Out:
# Index(['American Beauty (1999)', 'Being John Malkovich (1999)',
#        'Braveheart (1995)', 'Casablanca (1942)',
#        'E.T. the Extra-Terrestrial (1982)', 'Fargo (1996)',
#        'Forrest Gump (1994)', 'L.A. Confidential (1997)', 'Matrix, The (1999)',
#        'Princess Bride, The (1987)', 'Pulp Fiction (1994)',
#        'Raiders of the Lost Ark (1981)', 'Saving Private Ryan (1998)',
#        'Schindler's List (1993)', 'Shakespeare in Love (1998)',
#        'Shawshank Redemption, The (1994)', 'Silence of the Lambs, The (1991)',
#        'Sixth Sense, The (1999)', 'Star Wars: Episode IV - A New Hope (1977)',
#        'Star Wars: Episode V - The Empire Strikes Back (1980)',
#        'Toy Story (1995)', 'Wizard of Oz, The (1939)'],
#       dtype='object', name='영화제목')

# %%
# isin() 함수활용
movies[movies.영화제목.isin(여성인기영화.index)]
# Out:
#       영화아이디                                               영화제목  \
# 0         1                                   Toy Story (1995)
# 108     110                                  Braveheart (1995)
# 257     260          Star Wars: Episode IV - A New Hope (1977)
# 293     296                                Pulp Fiction (1994)
# 315     318                   Shawshank Redemption, The (1994)
# 352     356                                Forrest Gump (1994)
# 523     527                            Schindler's List (1993)
# 589     593                   Silence of the Lambs, The (1991)
# 604     608                                       Fargo (1996)
# 900     912                                  Casablanca (1942)
# 907     919                           Wizard of Oz, The (1939)
# 1081   1097                  E.T. the Extra-Terrestrial (1982)
# 1178   1196  Star Wars: Episode V - The Empire Strikes Back...
# 1179   1197                         Princess Bride, The (1987)
# 1180   1198                     Raiders of the Lost Ark (1981)
# 1575   1617                           L.A. Confidential (1997)
# 1959   2028                         Saving Private Ryan (1998)
# 2327   2396                         Shakespeare in Love (1998)
# 2502   2571                                 Matrix, The (1999)
# 2693   2762                            Sixth Sense, The (1999)
# 2789   2858                             American Beauty (1999)
# 2928   2997                        Being John Malkovich (1999)
#
#                                       장르
# 0            Animation|Children's|Comedy
# 108                     Action|Drama|War
# 257      Action|Adventure|Fantasy|Sci-Fi
# 293                          Crime|Drama
# 315                                Drama
# 352                   Comedy|Romance|War
# 523                            Drama|War
# 589                       Drama|Thriller
# 604                 Crime|Drama|Thriller
# 900                    Drama|Romance|War
# 907   Adventure|Children's|Drama|Musical
# 1081     Children's|Drama|Fantasy|Sci-Fi
# 1178   Action|Adventure|Drama|Sci-Fi|War
# 1179     Action|Adventure|Comedy|Romance
# 1180                    Action|Adventure
# 1575    Crime|Film-Noir|Mystery|Thriller
# 1959                    Action|Drama|War
# 2327                      Comedy|Romance
# 2502              Action|Sci-Fi|Thriller
# 2693                            Thriller
# 2789                        Comedy|Drama
# 2928                              Comedy

# %%
#2. 여성인기 영화와 movies 데이터를 합치기
# merge()활용
# reset_index() 활용해서 row를 column으로 바꿈
여성인기영화.reset_index()
# Out:
#                                                  영화제목      mean  count
# 0                              American Beauty (1999)  4.238901  946.0
# 1                         Being John Malkovich (1999)  4.159930  569.0
# 2                                   Braveheart (1995)  4.016484  546.0
# 3                                   Casablanca (1942)  4.300990  505.0
# 4                   E.T. the Extra-Terrestrial (1982)  4.089850  601.0
# 5                                        Fargo (1996)  4.217656  657.0
# 6                                 Forrest Gump (1994)  4.045031  644.0
# 7                            L.A. Confidential (1997)  4.106007  566.0
# 8                                  Matrix, The (1999)  4.128405  514.0
# 9                          Princess Bride, The (1987)  4.342767  636.0
# 10                                Pulp Fiction (1994)  4.071956  542.0
# 11                     Raiders of the Lost Ark (1981)  4.332168  572.0
# 12                         Saving Private Ryan (1998)  4.114783  575.0
# 13                            Schindler's List (1993)  4.562602  615.0
# 14                         Shakespeare in Love (1998)  4.181704  798.0
# 15                   Shawshank Redemption, The (1994)  4.539075  627.0
# 16                   Silence of the Lambs, The (1991)  4.271955  706.0
# 17                            Sixth Sense, The (1999)  4.477410  664.0
# 18          Star Wars: Episode IV - A New Hope (1977)  4.302937  647.0
# 19  Star Wars: Episode V - The Empire Strikes Back...  4.106481  648.0
# 20                                   Toy Story (1995)  4.187817  591.0
# 21                           Wizard of Oz, The (1939)  4.355030  507.0

# %%
pd.merge(여성인기영화.reset_index(), movies)
# Out:
#                                                  영화제목      mean  count  영화아이디  \
# 0                              American Beauty (1999)  4.238901  946.0   2858
# 1                         Being John Malkovich (1999)  4.159930  569.0   2997
# 2                                   Braveheart (1995)  4.016484  546.0    110
# 3                                   Casablanca (1942)  4.300990  505.0    912
# 4                   E.T. the Extra-Terrestrial (1982)  4.089850  601.0   1097
# 5                                        Fargo (1996)  4.217656  657.0    608
# 6                                 Forrest Gump (1994)  4.045031  644.0    356
# 7                            L.A. Confidential (1997)  4.106007  566.0   1617
# 8                                  Matrix, The (1999)  4.128405  514.0   2571
# 9                          Princess Bride, The (1987)  4.342767  636.0   1197
# 10                                Pulp Fiction (1994)  4.071956  542.0    296
# 11                     Raiders of the Lost Ark (1981)  4.332168  572.0   1198
# 12                         Saving Private Ryan (1998)  4.114783  575.0   2028
# 13                            Schindler's List (1993)  4.562602  615.0    527
# 14                         Shakespeare in Love (1998)  4.181704  798.0   2396
# 15                   Shawshank Redemption, The (1994)  4.539075  627.0    318
# 16                   Silence of the Lambs, The (1991)  4.271955  706.0    593
# 17                            Sixth Sense, The (1999)  4.477410  664.0   2762
# 18          Star Wars: Episode IV - A New Hope (1977)  4.302937  647.0    260
# 19  Star Wars: Episode V - The Empire Strikes Back...  4.106481  648.0   1196
# 20                                   Toy Story (1995)  4.187817  591.0      1
# 21                           Wizard of Oz, The (1939)  4.355030  507.0    919
#
#                                     장르
# 0                         Comedy|Drama
# 1                               Comedy
# 2                     Action|Drama|War
# 3                    Drama|Romance|War
# 4      Children's|Drama|Fantasy|Sci-Fi
# 5                 Crime|Drama|Thriller
# 6                   Comedy|Romance|War
# 7     Crime|Film-Noir|Mystery|Thriller
# 8               Action|Sci-Fi|Thriller
# 9      Action|Adventure|Comedy|Romance
# 10                         Crime|Drama
# 11                    Action|Adventure
# 12                    Action|Drama|War
# 13                           Drama|War
# 14                      Comedy|Romance
# 15                               Drama
# 16                      Drama|Thriller
# 17                            Thriller
# 18     Action|Adventure|Fantasy|Sci-Fi
# 19   Action|Adventure|Drama|Sci-Fi|War
# 20         Animation|Children's|Comedy
# 21  Adventure|Children's|Drama|Musical

# %%
#concat() 활용
#set_index() 활용하면 칼럼이 로우로 바뀜
movies.set_index('영화제목')
# Out:
#                                     영화아이디                            장르
# 영화제목
# Toy Story (1995)                        1   Animation|Children's|Comedy
# Jumanji (1995)                          2  Adventure|Children's|Fantasy
# Grumpier Old Men (1995)                 3                Comedy|Romance
# Waiting to Exhale (1995)                4                  Comedy|Drama
# Father of the Bride Part II (1995)      5                        Comedy
# ...                                   ...                           ...
# Meet the Parents (2000)              3948                        Comedy
# Requiem for a Dream (2000)           3949                         Drama
# Tigerland (2000)                     3950                         Drama
# Two Family House (2000)              3951                         Drama
# Contender, The (2000)                3952                Drama|Thriller
#
# [3883 rows x 2 columns]

# %%
# 여성인기영화 에 있는 부분만 합치려면 join= inner 사용 (둘 다 있는 내용만 합침)
pd.concat([여성인기영화,movies.set_index('영화제목')], axis=1, join='inner')
# Out:
#                                                         mean  count  영화아이디  \
# 영화제목
# American Beauty (1999)                              4.238901  946.0   2858
# Being John Malkovich (1999)                         4.159930  569.0   2997
# Braveheart (1995)                                   4.016484  546.0    110
# Casablanca (1942)                                   4.300990  505.0    912
# E.T. the Extra-Terrestrial (1982)                   4.089850  601.0   1097
# Fargo (1996)                                        4.217656  657.0    608
# Forrest Gump (1994)                                 4.045031  644.0    356
# L.A. Confidential (1997)                            4.106007  566.0   1617
# Matrix, The (1999)                                  4.128405  514.0   2571
# Princess Bride, The (1987)                          4.342767  636.0   1197
# Pulp Fiction (1994)                                 4.071956  542.0    296
# Raiders of the Lost Ark (1981)                      4.332168  572.0   1198
# Saving Private Ryan (1998)                          4.114783  575.0   2028
# Schindler's List (1993)                             4.562602  615.0    527
# Shakespeare in Love (1998)                          4.181704  798.0   2396
# Shawshank Redemption, The (1994)                    4.539075  627.0    318
# Silence of the Lambs, The (1991)                    4.271955  706.0    593
# Sixth Sense, The (1999)                             4.477410  664.0   2762
# Star Wars: Episode IV - A New Hope (1977)           4.302937  647.0    260
# Star Wars: Episode V - The Empire Strikes Back ...  4.106481  648.0   1196
# Toy Story (1995)                                    4.187817  591.0      1
# Wizard of Oz, The (1939)                            4.355030  507.0    919
#
#                                                                                     장르
# 영화제목
# American Beauty (1999)                                                    Comedy|Drama
# Being John Malkovich (1999)                                                     Comedy
# Braveheart (1995)                                                     Action|Drama|War
# Casablanca (1942)                                                    Drama|Romance|War
# E.T. the Extra-Terrestrial (1982)                      Children's|Drama|Fantasy|Sci-Fi
# Fargo (1996)                                                      Crime|Drama|Thriller
# Forrest Gump (1994)                                                 Comedy|Romance|War
# L.A. Confidential (1997)                              Crime|Film-Noir|Mystery|Thriller
# Matrix, The (1999)                                              Action|Sci-Fi|Thriller
# Princess Bride, The (1987)                             Action|Adventure|Comedy|Romance
# Pulp Fiction (1994)                                                        Crime|Drama
# Raiders of the Lost Ark (1981)                                        Action|Adventure
# Saving Private Ryan (1998)                                            Action|Drama|War
# Schindler's List (1993)                                                      Drama|War
# Shakespeare in Love (1998)                                              Comedy|Romance
# Shawshank Redemption, The (1994)                                                 Drama
# Silence of the Lambs, The (1991)                                        Drama|Thriller
# Sixth Sense, The (1999)                                                       Thriller
# Star Wars: Episode IV - A New Hope (1977)              Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode V - The Empire Strikes Back ...   Action|Adventure|Drama|Sci-Fi|War
# Toy Story (1995)                                           Animation|Children's|Comedy
# Wizard of Oz, The (1939)                            Adventure|Children's|Drama|Musical

# %%
ex2 =pd.concat([여성인기영화,movies.set_index('영화제목')], axis=1, join='inner').장르

# %%
ex2.value_counts()
# Out:
# Action|Drama|War                      2
# Children's|Drama|Fantasy|Sci-Fi       1
# Adventure|Children's|Drama|Musical    1
# Thriller                              1
# Crime|Drama|Thriller                  1
# Action|Adventure|Comedy|Romance       1
# Comedy|Romance|War                    1
# Comedy                                1
# Animation|Children's|Comedy           1
# Drama|War                             1
# Action|Adventure                      1
# Action|Sci-Fi|Thriller                1
# Drama|Thriller                        1
# Action|Adventure|Fantasy|Sci-Fi       1
# Crime|Drama                           1
# Action|Adventure|Drama|Sci-Fi|War     1
# Comedy|Drama                          1
# Drama|Romance|War                     1
# Comedy|Romance                        1
# Crime|Film-Noir|Mystery|Thriller      1
# Drama                                 1
# Name: 장르, dtype: int64

# %%
#위에 영화 장르에서 Action|Drama|War 에 있는 '|' 제거
ex2.str.split('|')
# expand=True 로 하면 column으로 해줌(기본적으로 False)
ex2_expand = ex2.str.split('|', expand=True)

# %%
ex2_expand
# Out:
#                                                              0           1  \
# 영화제목
# American Beauty (1999)                                  Comedy       Drama
# Being John Malkovich (1999)                             Comedy        None
# Braveheart (1995)                                       Action       Drama
# Casablanca (1942)                                        Drama     Romance
# E.T. the Extra-Terrestrial (1982)                   Children's       Drama
# Fargo (1996)                                             Crime       Drama
# Forrest Gump (1994)                                     Comedy     Romance
# L.A. Confidential (1997)                                 Crime   Film-Noir
# Matrix, The (1999)                                      Action      Sci-Fi
# Princess Bride, The (1987)                              Action   Adventure
# Pulp Fiction (1994)                                      Crime       Drama
# Raiders of the Lost Ark (1981)                          Action   Adventure
# Saving Private Ryan (1998)                              Action       Drama
# Schindler's List (1993)                                  Drama         War
# Shakespeare in Love (1998)                              Comedy     Romance
# Shawshank Redemption, The (1994)                         Drama        None
# Silence of the Lambs, The (1991)                         Drama    Thriller
# Sixth Sense, The (1999)                               Thriller        None
# Star Wars: Episode IV - A New Hope (1977)               Action   Adventure
# Star Wars: Episode V - The Empire Strikes Back ...      Action   Adventure
# Toy Story (1995)                                     Animation  Children's
# Wizard of Oz, The (1939)                             Adventure  Children's
#
#                                                            2         3     4
# 영화제목
# American Beauty (1999)                                  None      None  None
# Being John Malkovich (1999)                             None      None  None
# Braveheart (1995)                                        War      None  None
# Casablanca (1942)                                        War      None  None
# E.T. the Extra-Terrestrial (1982)                    Fantasy    Sci-Fi  None
# Fargo (1996)                                        Thriller      None  None
# Forrest Gump (1994)                                      War      None  None
# L.A. Confidential (1997)                             Mystery  Thriller  None
# Matrix, The (1999)                                  Thriller      None  None
# Princess Bride, The (1987)                            Comedy   Romance  None
# Pulp Fiction (1994)                                     None      None  None
# Raiders of the Lost Ark (1981)                          None      None  None
# Saving Private Ryan (1998)                               War      None  None
# Schindler's List (1993)                                 None      None  None
# Shakespeare in Love (1998)                              None      None  None
# Shawshank Redemption, The (1994)                        None      None  None
# Silence of the Lambs, The (1991)                        None      None  None
# Sixth Sense, The (1999)                                 None      None  None
# Star Wars: Episode IV - A New Hope (1977)            Fantasy    Sci-Fi  None
# Star Wars: Episode V - The Empire Strikes Back ...     Drama    Sci-Fi   War
# Toy Story (1995)                                      Comedy      None  None
# Wizard of Oz, The (1939)                               Drama   Musical  None

# %%
장르1 = ex2_expand[0].value_counts()
장르2 = ex2_expand[1].value_counts()
장르3 = ex2_expand[2].value_counts()
장르4 = ex2_expand[3].value_counts()
장르5 = ex2_expand[4].value_counts()

# %%
장르1
# Out:
# Action        7
# Comedy        4
# Drama         4
# Crime         3
# Children's    1
# Animation     1
# Adventure     1
# Thriller      1
# Name: 0, dtype: int64

# %%
# index가 다르면 사칙연산시에 NaN값 반환 그래서 fill_value=0 로 넣어서 index가 서로 다르면 다른 인덱스에 0의 값이 있다고 해서 계산

장르1.add(장르5, fill_value =0)
# Out:
# Action        7.0
# Adventure     1.0
# Animation     1.0
# Children's    1.0
# Comedy        4.0
# Crime         3.0
# Drama         4.0
# Thriller      1.0
# War           1.0
# dtype: float64

# %%
여성인기장르 = Series(dtype='float64')
for col in ex2_expand.columns:
    장르 = ex2_expand[col].value_counts()
    여성인기장르 = 여성인기장르.add(장르, fill_value =0)

# %%
여성인기장르
# Out:
# Action         7.0
# Adventure      5.0
# Animation      1.0
# Children's     3.0
# Comedy         6.0
# Crime          3.0
# Drama         12.0
# Fantasy        2.0
# Film-Noir      1.0
# Musical        1.0
# Mystery        1.0
# Romance        4.0
# Sci-Fi         4.0
# Thriller       5.0
# War            6.0
# dtype: float64

# %%
여성인기장르.sort_values(ascending=False)
# Out:
# Drama         12.0
# Action         7.0
# Comedy         6.0
# War            6.0
# Adventure      5.0
# Thriller       5.0
# Romance        4.0
# Sci-Fi         4.0
# Children's     3.0
# Crime          3.0
# Fantasy        2.0
# Animation      1.0
# Film-Noir      1.0
# Musical        1.0
# Mystery        1.0
# dtype: float64

# %% [markdown]
# ## [실습 #3] 남자와 여자의 호불호가 크게 갈리는 영화 10개 찾기
# 전체 평점의 개수가 500개 이상인 영화만 대상으로 함.

# %%
ex3 = data.pivot_table(index='영화제목', columns='성별', values='평점', aggfunc =['mean','count'])

# %%
#1.전체 평점의 개수가 500개 이상인 영화만 선택
ex3 = ex3[ex3[('count','F')] + ex3[('count','M')] >=500]
ex3
# Out:
#                                            mean            count
# 성별                                            F         M      F       M
# 영화제목
# 10 Things I Hate About You (1999)      3.646552  3.311966  232.0   468.0
# 101 Dalmatians (1961)                  3.791444  3.500000  187.0   378.0
# 12 Angry Men (1957)                    4.184397  4.328421  141.0   475.0
# 13th Warrior, The (1999)               3.112000  3.168000  125.0   625.0
# 20,000 Leagues Under the Sea (1954)    3.670103  3.709205   97.0   478.0
# ...                                         ...       ...    ...     ...
# X-Files: Fight the Future, The (1998)  3.489474  3.493797  190.0   806.0
# X-Men (2000)                           3.682310  3.851702  277.0  1234.0
# You've Got Mail (1998)                 3.542424  3.275591  330.0   508.0
# Young Frankenstein (1974)              4.289963  4.239177  269.0   924.0
# Young Guns (1988)                      3.371795  3.425620   78.0   484.0
#
# [618 rows x 4 columns]

# %%
# 2. 남자평점과 여자 평점의 차이 계산
ex3['diff'] = abs(ex3[('mean','F')] - ex3[('mean','M')])

# %%
ex3.nlargest(10,'diff')
# Out:
#                                             mean            count         \
# 성별                                             F         M      F      M
# 영화제목
# Dirty Dancing (1987)                    3.790378  2.959596  291.0  396.0
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300   99.0  723.0
# Dumb & Dumber (1994)                    2.697987  3.336595  149.0  511.0
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283   74.0  474.0
# Grease (1978)                           3.975265  3.367041  283.0  534.0
# Caddyshack (1980)                       3.396135  3.969737  207.0  760.0
# Animal House (1978)                     3.628906  4.167192  256.0  951.0
# Exorcist, The (1973)                    3.537634  4.067239  186.0  699.0
# Rocky Horror Picture Show, The (1975)   3.673016  3.160131  315.0  918.0
# Big Trouble in Little China (1986)      2.987952  3.485030   83.0  501.0
#
#                                             diff
# 성별
# 영화제목
# Dirty Dancing (1987)                    0.830782
# Good, The Bad and The Ugly, The (1966)  0.726351
# Dumb & Dumber (1994)                    0.638608
# Evil Dead II (Dead By Dawn) (1987)      0.611985
# Grease (1978)                           0.608224
# Caddyshack (1980)                       0.573602
# Animal House (1978)                     0.538286
# Exorcist, The (1973)                    0.529605
# Rocky Horror Picture Show, The (1975)   0.512885
# Big Trouble in Little China (1986)      0.497078

# %% [markdown]
# ## [실습 #4] 연령대 별로 영화 평점 분석하기
# 연령대(10대 미만, 10대, 20대, ...50대) 컬럼을 추가한 후, 영화별 연령대별 영화평점 구하기

# %%
def calculate_ages(x):
    if x<10:
        return '10대 미만'
    elif x<20:
        return '10대'
    elif x<30:
        return '20대'
    elif x<40:
        return '30대'
    elif x<50:
        return '40대'
    else:
        return '50대'

# %%
calculate_ages(30)
# Out:
# '30대'

# %%
연령대 = data.연령.apply(calculate_ages)
# data.연령.apply(lambda x:calculate_ages(x))

# %%
data['연령대'] = 연령대
data
# Out:
#          사용자아이디 성별  연령  직업     지역  영화아이디  평점      타임스탬프  \
# 0             1  F   1  10  48067   1193   5  978300760
# 1             2  M  56  16  70072   1193   5  978298413
# 2            12  M  25  12  32793   1193   4  978220179
# 3            15  M  25   7  22903   1193   4  978199279
# 4            17  M  50   1  95350   1193   5  978158471
# ...         ... ..  ..  ..    ...    ...  ..        ...
# 1000204    5949  M  18  17  47901   2198   5  958846401
# 1000205    5675  M  35  14  30030   2703   3  976029116
# 1000206    5780  M  18  17  92886   2845   1  958153068
# 1000207    5851  F  18  20  55410   3607   5  957756608
# 1000208    5938  M  25   1  35401   2909   4  957273353
#
#                                                 영화제목                    장르  \
# 0             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 1             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 2             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 3             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 4             One Flew Over the Cuckoo's Nest (1975)                 Drama
# ...                                              ...                   ...
# 1000204                           Modulations (1998)           Documentary
# 1000205                        Broken Vessels (1998)                 Drama
# 1000206                            White Boys (1999)                 Drama
# 1000207                     One Little Indian (1973)  Comedy|Drama|Western
# 1000208  Five Wives, Three Secretaries and Me (1998)           Documentary
#
#             연령대
# 0        10대 미만
# 1           50대
# 2           20대
# 3           20대
# 4           50대
# ...         ...
# 1000204     10대
# 1000205     30대
# 1000206     10대
# 1000207     10대
# 1000208     20대
#
# [1000209 rows x 11 columns]

# %%
ex4 = data.pivot_table(index='영화제목', columns='연령대', values='평점', aggfunc =['mean','count'])

# %%
ex4
# Out:
#                                                 mean                      \
# 연령대                                              10대    10대 미만       20대
# 영화제목
# $1,000,000 Duck (1971)                      3.000000       NaN  3.090909
# 'Night Mother (1986)                        4.666667  2.000000  3.423077
# 'Til There Was You (1997)                   2.500000  3.500000  2.666667
# 'burbs, The (1989)                          3.244444  4.500000  2.652174
# ...And Justice for All (1979)               3.428571  3.000000  3.724138
# ...                                              ...       ...       ...
# Zed & Two Noughts, A (1985)                 3.000000  1.000000  3.375000
# Zero Effect (1998)                          3.883333  4.125000  3.715278
# Zero Kelvin (Kjærlighetens kjøtere) (1995)       NaN       NaN       NaN
# Zeus and Roxanne (1997)                     2.500000  1.500000  2.833333
# eXistenZ (1999)                             3.289157  3.142857  3.234973
#
#                                                                           \
# 연령대                                              30대       40대       50대
# 영화제목
# $1,000,000 Duck (1971)                      3.133333  2.000000  2.750000
# 'Night Mother (1986)                        2.904762  3.833333  3.750000
# 'Til There Was You (1997)                   2.900000  2.333333  2.600000
# 'burbs, The (1989)                          2.818182  2.545455  3.100000
# ...And Justice for All (1979)               3.657143  4.100000  3.674419
# ...                                              ...       ...       ...
# Zed & Two Noughts, A (1985)                 3.777778  4.000000  3.000000
# Zero Effect (1998)                          3.608696  3.764706  3.769231
# Zero Kelvin (Kjærlighetens kjøtere) (1995)  3.500000       NaN       NaN
# Zeus and Roxanne (1997)                     3.500000  1.000000       NaN
# eXistenZ (1999)                             3.364865  3.222222  3.103448
#
#                                            count                            \
# 연령대                                          10대 10대 미만    20대   30대   40대
# 영화제목
# $1,000,000 Duck (1971)                       6.0    NaN   11.0  15.0   1.0
# 'Night Mother (1986)                         3.0    2.0   26.0  21.0   6.0
# 'Til There Was You (1997)                    8.0    2.0   24.0  10.0   3.0
# 'burbs, The (1989)                          90.0    2.0  115.0  55.0  11.0
# ...And Justice for All (1979)                7.0    1.0   58.0  70.0  20.0
# ...                                          ...    ...    ...   ...   ...
# Zed & Two Noughts, A (1985)                  1.0    1.0   16.0   9.0   1.0
# Zero Effect (1998)                          60.0    8.0  144.0  46.0  17.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)   NaN    NaN    NaN   2.0   NaN
# Zeus and Roxanne (1997)                      4.0    6.0    6.0   6.0   1.0
# eXistenZ (1999)                             83.0   14.0  183.0  74.0  27.0
#
#
# 연령대                                          50대
# 영화제목
# $1,000,000 Duck (1971)                       4.0
# 'Night Mother (1986)                        12.0
# 'Til There Was You (1997)                    5.0
# 'burbs, The (1989)                          30.0
# ...And Justice for All (1979)               43.0
# ...                                          ...
# Zed & Two Noughts, A (1985)                  1.0
# Zero Effect (1998)                          26.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)   NaN
# Zeus and Roxanne (1997)                      NaN
# eXistenZ (1999)                             29.0
#
# [3706 rows x 12 columns]
